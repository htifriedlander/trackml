# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from trackml.dataset import load_event, load_dataset 
from trackml.randomize import shuffle_hits
from trackml.score import score_event 
import os
import math
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import time
from multiprocessing import Pool
# %matplotlib notebook
# %run utils.ipynb
#%run all_create.ipynb

# %% [raw]
# hits, cells, particles, truth = load_data_single_event(1050)
# hits_from_seeds = np.load('./hits_from_seeds.npy')
# print (hits.head())
# hits_array = np.array (hits.get_values())
# mapping = np.argsort (hits_array[:,0])
# hits_array = hits_array[mapping]
# print (hits_array)
# hits.head()

# %%
"""
Encapsulates the NN used for next-hit prediction 
"""
class predict_engine(): 
    N_steps = 10
    N_INPUT_FEATURES = 5
    N_NEURONS = 200
    N_OUTPUTS = 3
    MODEL_PATH = './checkpoints/baseline-idealv4/-33103.meta'
    
    def __init__(self):
        init = tf.global_variables_initializer()
        
        infSess = tf.Session() 
        init.run(session = infSess)
            
        saver = tf.train.import_meta_graph(self.MODEL_PATH)
        graph = saver.restore(infSess,'./checkpoints/baseline-idealv4/-33103' )
        #graph = tf.get_default_graph #hopefully this always points to the right one...
        predict_op = infSess.graph.get_tensor_by_name("print_op:0")
        self.predict_op = predict_op
        self.infSess = infSess 
    
    def pred(self, seed):
        #print('seed shape is:')
        #print(seed.shape)
        pad_zeros = 10 - len(seed)
        x_data = np.array([np.pad(seed, ((0, pad_zeros), (0,0)), 'constant')])
        #print('x_data shape is:')
        #print(x_data.shape)
        
        inputs = tf.placeholder(tf.float32, [None, 10, 5])
        input_tensor = self.infSess.graph.get_tensor_by_name('input_ph:0')
        prediction = self.infSess.run(self.predict_op, feed_dict={input_tensor:x_data})
        #print('input was: ')
        #print(x_data)
        #print('\n')
        #print('pred is: ')
        #print(prediction)
        return prediction[0]
    
    def close(self):
        self.infSess.close()

# %% [raw]
# #tf_init_start = time.time()
# prediction = predict_engine()
# prediction.load()
# #tf_init_end = time.time()
#
# #init_seed_start = time.time()
# seeds = next_seed(hits_from_seeds)
# #init_seed_end = time.time()
#
#
# hits_from_tracks = []
# mse_hitid = []
# #austin_start_time = time.time()
#
# #total_pred_time = 0
# #total_track_pass_time = 0
# #get_xyz_total = 0
# #get_hit_info_total = 0
# #mse_total = 0
# #process_time_total = 0
# for i in range(5):#change it back to 5
#     mse_hitid.append([])
#     feed_seed = next(seeds)[0]
#     #print('feed_seed is: ')
#     #print(feed_seed)
#
#     for j in range(7):
#         #print("j: ", j)
#
#         #pred_start = time.time()
#         predicted_hit = prediction.pred(feed_seed)[j+2]
#         #pred_end = time.time()
#
#
#         #print('NN pred time: ' + str(pred_end -pred_start))
#
#         predicted_hit_xyz = polar_to_cartesian(predicted_hit[0], predicted_hit[1], predicted_hit[2])
#
#
#         #track_pass_init = time.time()
#         real_hit_id = calc_dist(predicted_hit_xyz[0], predicted_hit_xyz[1], predicted_hit_xyz[2], hits_array)
#         #track_pass_end = time.time()
#
#
#         #get_xyz_init = time.time()
#         real_hit = get_xyz(real_hit_id)
#         #get_xyz_end = time.time()
#         #get_xyz_total +=(get_xyz_end - get_xyz_init)
#
#         #get_hit_info_init = time.time()
#         l, v, hit_id = get_hit_info(real_hit[0], real_hit[1], real_hit[2]) #change function to take hits df as parameter
#         #get_hit_info_end = time.time()
#         #get_hit_info_total += (get_hit_info_end - get_hit_info_init)
#
#         #mse_init = time.time()
#         mse = distance_between_two_points(real_hit, polar_to_cartesian(predicted_hit[0], predicted_hit[1], predicted_hit[2]))
#         #mse_end = time.time()
#         #reshape_init = time.time()
#         mse_hitid[i].extend([[mse, real_hit_id]])
#         real_hit.extend([l,v])
#         reshaped_real_hit = np.asarray(real_hit).reshape(1, 5)
#         feed_seed = np.append(feed_seed, reshaped_real_hit, axis=0)
#         #reshape_end = time.time()
#
#
#         #mse_total += (mse_end - mse_init)
#         #process_time_total += (reshape_end - reshape_init)
#         #total_pred_time += (pred_end - pred_start)
#         #total_track_pass_time +=(track_pass_end - track_pass_init)
#         #print('track pass time: '+str(track_pass_end - track_pass_init))
#     #print ('this time it was ' + str (pred_end - pred_start))
#     #print ('but track pass time was ' + str (track_pass_end - track_pass_init))
#     hits_from_tracks.append(feed_seed)
# #final_end = time.time()
# #print('total runtime: ' + str(final_end -austin_start_time))
# #print('get xyz_total time: ',get_xyz_total)
# #print('get hit info total: ',get_hit_info_total)
# #print('tf graph load: ' + str(tf_init_end - tf_init_start))
# #print('total NN pred time: ',total_pred_time)
# #print('total track pass time: ',total_track_pass_time)
# #print('total mse calc time: ', mse_total)
# #print('reshaping time: ', process_time_total)

# %%
"""
mod this for lstm input 
"""

def reconstruct_track_from_seed (feed_seed, hits_array): #assumes a global predict_engine() named predictionv2 exists 
    mse_hitid = []
    for j in range(7):
        predicted_hit = predictionv2.pred(feed_seed)[j+2]
        predicted_hit_xyz = polar_to_cartesian(predicted_hit[0], predicted_hit[1], predicted_hit[2])
        (real_hit_id, dist_squared) = calc_dist(predicted_hit_xyz[0], predicted_hit_xyz[1], predicted_hit_xyz[2], hits_array)
        hit_index = int (np.round (real_hit_id - 1))
        assert (hits_array[hit_index,0] == real_hit_id)
        x, y, z, l, v = hits_array[hit_index,1], hits_array[hit_index,2], hits_array[hit_index,3], hits_array[hit_index,5], hits_array[hit_index,4]
        r, phi, z = cartesian_to_3d_polar (x, y, z)
        to_append = np.array ([[r, phi, z, l, v]])
        feed_seed = np.append (feed_seed, to_append, axis = 0)
        
        #print('feed seed shape is: ', feed_seed.shape)
        #print('feed seed is: ',feed_seed)
        mse_hitid.append ([dist_squared, real_hit_id])
        continue
    return (feed_seed, mse_hitid)

def reconstruct_event (seeds, hits):
    hits_array = np.array (hits.get_values())
    hits_from_seeds = rpzlv_from_seeds (seeds, hits)
    seeds_generated = next_seed(hits_from_seeds)
    hits_from_tracks = []
    mse_hitid = []
    count = 0
    total_seeds = len(seeds)
    print('num seeds to reconstruct from: ', total_seeds)
    #total_time = 0
    hashes = [x for x in range(0,100,1)]
    for feed_seed in seeds_generated:
        init = time.time()
        feed_seed = np.array (feed_seed[0])
        seed_mse_hitid = [[0, seeds[count,0]],[0, seeds[count,1]],[0, seeds[count,2]]]
        (feed_seed, track_mse_hitid) = reconstruct_track_from_seed (feed_seed, hits_array)
        hits_from_tracks.append (feed_seed)
        mse_hitid.append (seed_mse_hitid + track_mse_hitid)
        count += 1
        #per_track_time = time.time() - init
        #print('time taken to reconstruct 1 track: ', per_track_time)
        #total_time += per_track_time
        
        
        if int(count/total_seeds) in hashes:
            hashes.remove(int(count/total_seeds))
            print('% seeds processed: ', count/total_seeds)
            print('elapsed time: ', time.time()-init )
    return (hits_from_tracks, mse_hitid)


def reconstruct_test_events ():
    itr = load_dataset ('./data/test_data', parts = ['hits'])
    for event_data in itr:
        event_id = event_data[0]
        print ('now working on event number ' + str (event_id))
        if (event_id <= 43):
            continue
        hits = event_data[1]
        hits_trans = trans_to_cylindrical (hits)
        seeds = np.load ('./seeds/test_event_' + str(event_id) + '_.npy')
        yield reconstruct_event (seeds, hits), event_id#yield (hits_from_event, hit_ids)

# %%
"""
Experimental stuff...
"""


predictionv2 = predict_engine()
hits, _, _,_ = load_data_single_event(1050)
test_seeds = np.load('./seeds/training_event_1050.npy')

test_seeds_slice = [:10]
#test_seeds_slice = test_seeds[:100]
init = time.time()
hits_from_tracks , mse_hitids = reconstruct_event(test_seeds, hits)
np.save ('./experimental/hits_from_tracks_event_' + str (1050) + '.npy', np.array (hits_from_tracks))
np.save ('./experimental/mse_hitid_event_' + str (1050) + '.npy', np.array (mse_hitids))
print('reconstruction event time: ',time.time()-init)
predictionv2.close()
#print('sample of hits_from_tracks', hits_from_tracks[:5])
#print('sample of mse_hitids', mse_hitids[:5])
# Out:
# INFO:tensorflow:Restoring parameters from ./checkpoints/baseline-idealv4/-33103
# num seeds to reconstruct from:  16517
# % seeds processed:  6.054368226675546e-05
# elapsed time:  0.4321720600128174
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-7e7562375646> in <module>()
#       9 #test_seeds_slice = test_seeds[:100]
#      10 init = time.time()
# ---> 11 hits_from_tracks , mse_hitids = reconstruct_event(test_seeds, hits)
#      12 np.save ('./experimental/hits_from_tracks_event_' + str (1050) + '.npy', np.array (hits_from_tracks))
#      13 np.save ('./experimental/mse_hitid_event_' + str (1050) + '.npy', np.array (mse_hitids))
#
# <ipython-input-4-cc03b50b4b58> in reconstruct_event(seeds, hits)
#      37         feed_seed = np.array (feed_seed[0])
#      38         seed_mse_hitid = [[0, seeds[count,0]],[0, seeds[count,1]],[0, seeds[count,2]]]
# ---> 39         (feed_seed, track_mse_hitid) = reconstruct_track_from_seed (feed_seed, hits_array)
#      40         hits_from_tracks.append (feed_seed)
#      41         mse_hitid.append (seed_mse_hitid + track_mse_hitid)
#
# <ipython-input-4-cc03b50b4b58> in reconstruct_track_from_seed(feed_seed, hits_array)
#       6     mse_hitid = []
#       7     for j in range(7):
# ----> 8         predicted_hit = predictionv2.pred(feed_seed)[j+2]
#       9         predicted_hit_xyz = polar_to_cartesian(predicted_hit[0], predicted_hit[1], predicted_hit[2])
#      10         (real_hit_id, dist_squared) = calc_dist(predicted_hit_xyz[0], predicted_hit_xyz[1], predicted_hit_xyz[2], hits_array)
#
# <ipython-input-2-4652a5a44c21> in pred(self, seed)
#      32         inputs = tf.placeholder(tf.float32, [None, 10, 5])
#      33         input_tensor = self.infSess.graph.get_tensor_by_name('input_ph:0')
# ---> 34         prediction = self.infSess.run(self.predict_op, feed_dict={input_tensor:x_data})
#      35         #print('input was: ')
#      36         #print(x_data)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1308     def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1309       # Ensure any changes to the graph are reflected in the runtime.
# -> 1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
#    1312           options, feed_dict, fetch_list, target_list, run_metadata)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1356           with errors.raise_exception_on_not_ok_status() as status:
#    1357             tf_session.TF_ExtendGraph(self._session,
# -> 1358                                       graph_def.SerializeToString(), status)
#    1359           self._opened = True
#    1360
#
# KeyboardInterrupt:

# %%
len(test_seeds)

# %%
(((25.618842840194702/100)*len(test_seeds))/3600)

# %%
"""
stable stuff below

"""
prediction = predict_engine()
prediction.load()
start_time = time.time()
for (hits_from_tracks, mse_hitid), event_id in reconstruct_test_events():
    print ('now saving event number ' + str (event_id))
    print ('elapsed time is ' + str ((time.time() - start_time)/60/60) + ' hours.')
    np.save ('./reconstructed_test_events/hits_from_tracks_event_' + str (event_id) + '.npy', np.array (hits_from_tracks))
    np.save ('./reconstructed_test_events/mse_hitid_event_' + str (event_id) + '.npy', np.array (mse_hitid))

# %% [raw]
# start_time = time.time()
# prediction = predict_engine()
# prediction.load()
#
#
# counter = 0
#
# number_to_do = len (hits_from_seeds)
#
# for feed_seed in seeds:#change it back to 5
#     feed_seed = np.array (feed_seed[0])
#     (feed_seed, track_mse_hitid) = reconstruct_track_from_seed (feed_seed)
#     hits_from_tracks.append (feed_seed)
#     mse_hitid.append (track_mse_hitid)
#     #print (counter % int (number_to_do/100))
#     if (counter % int (number_to_do/100) k== 0):
#         print (counter/number_to_do)
#     counter += 1
#
# print (time.time() - start_time)

# %% [raw]
# start = time.time()
# prediction = predict_engine()
# prediction.load()
# hits, cells, particles, truth = load_data_single_event(1050)
# seeds = np.load ('./seeds/training_event_1050.npy')
# (hits_from_tracks, mse_hitid) = reconstruct_event (seeds, hits)
# np.save ('./hits_from_tracks.npy', np.array (hits_from_tracks))
# np.save ('./mse_hitid.npy', np.array (mse_hitid))
# print('pipeline time for single event:',time.time()-start)

# %%
#np.save ('./tracksToPlot.npy', np.array (hits_from_tracks))
